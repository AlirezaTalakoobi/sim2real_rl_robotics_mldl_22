# %%
import numpy as np

# %%
with open('lr_0.0001_nEpisodes_100000.txt','r') as f:
    r = f.readlines()
rewards =r[0][1:-2].split(', ')

# %%
rewards105 = np.array(rewards)
rewards105 = rewards105.astype(np.float)
# Out:
# C:\Users\MNPFZD01\AppData\Local\Temp\ipykernel_24640\1897185387.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   rewards105 = rewards105.astype(np.float)

# %%
rewards104 = np.array(rewards)
rewards104 = rewards104.astype(np.float)
# Out:
# C:\Users\MNPFZD01\AppData\Local\Temp\ipykernel_24640\4176078125.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   rewards104 = rewards104.astype(np.float)

# %%
import matplotlib.pyplot as plt
import numpy as np
  
# create data
# x = [3,3,3,3,3]
x = np.array(range(100000))


# plot lines
plt.plot(x[::1000],rewards104[::1000],label = "lr = 10e-4")
plt.plot( x[::1000],rewards105[::1000],label = "lr = 10e-5")


# plt.plot(x, np.sin(x), label = "curve 1")
# plt.plot(x, np.cos(x), label = "curve 2")
plt.legend()
plt.show()
